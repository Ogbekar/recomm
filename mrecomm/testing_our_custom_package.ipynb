# %%
import mrecomm

# %%
from mrecomm import recomm

# %%
MOVIES = ['Titanic',
          'Docker: Unleashed',
          'Julia: Elegant and Hip',
          'Python : The Slow Snake',
          'C: Kids these days dont know how to compile code',
          'Shawshank Redemption']

# %%
rec = recomm.RecommenderClass(MOVIES)

# %%
rec.recommend_movie()
# Out:
# 'Julia: Elegant and Hip'

# %%
import os
package_dir = os.path.dirname(mrecomm.__file__)

# %%
package_dir + 'data/movies.txt'
# Out:
# '/home/arjun/euclidean-eukalyptus-encounter-notes/11_week/mrecomm/mrecommdata/movies.txt'

# %%
f = open(package_dir + '/data/movies.txt')
new_movies = f.readlines()
new_movies
# Out:
# ['Scooby-Doo! Abracadabra-Doo (2010)\n',
#  'Christina P: Mother Inferior (2017)\n',
#  'Fay Grim (2006)\n',
#  'King of Kong, The (2007)\n',
#  'Pumpkin (2002)\n',
#  'Hercules (2014)\n',
#  'Audrey Rose (1977)\n',
#  'Fantastic Four: Rise of the Silver Surfer (2007)\n',
#  'Fuck You, Goethe (Fack Ju Göhte) (2013)\n',
#  'Goldfinger (1964)\n',
#  'Bartleby (2001)\n',
#  'Magnolia (1999)\n',
#  'V. I. Warshawski (1991)\n',
#  'Hail, Caesar! (2016)\n',
#  "While We're Young (2014)\n",
#  'Zipper (2015)\n',
#  'Johnny Belinda (1948)\n',
#  '1776 (1972)\n',
#  'Our Town (1940)\n',
#  'Pink Panther Strikes Again, The (1976)\n',
#  "I'm Still Here (2010)\n",
#  'Unknown White Male (2005)\n',
#  'Last Dragon, The (1985)\n',
#  'Jaws 2 (1978)\n',
#  'Prince of Tides, The (1991)\n',
#  'Heartless (2009)\n',
#  'Alice (Neco z Alenky) (1988)\n',
#  'Far from Heaven (2002)\n',
#  'King Kong Lives (1986)\n',
#  "Ocean's Eleven (2001)\n",
#  'Wizard of Oz, The (1939)\n',
#  'Undead (2003)\n',
# ...

# %%
rec = recomm.RecommenderClass(new_movies)
rec.recommend_movie()
# Out:
# 'Boxcar Bertha (1972)\n'
